# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as splt
import seaborn as sns
from sklearn.model_selection import cross_val_score

# %%
df = pd.read_csv(r'C:\users\anik\desktop\cardio_train.csv',sep=';')

# %%
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df['cardio'].value_counts()
# Out:
# cardio
# 0    35021
# 1    34979
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x='cardio')
# Out:
# C:\Users\Anik\anaconda3\envs\MLenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Anik\anaconda3\envs\MLenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Anik\anaconda3\envs\MLenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='cardio', ylabel='count'>

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.isna().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
sns.countplot(data=df, x='gender',hue='cardio',palette='colorblind', edgecolor=sns.color_palette('dark', n_colors=1))
# Out:
# C:\Users\Anik\anaconda3\envs\MLenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Anik\anaconda3\envs\MLenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Anik\anaconda3\envs\MLenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
df['yr']=(df['age']/365).round(0)

# %%
df['yr']
# Out:
# 0        50.0
# 1        55.0
# 2        52.0
# 3        48.0
# 4        48.0
#          ...
# 69995    53.0
# 69996    62.0
# 69997    52.0
# 69998    61.0
# 69999    56.0
# Name: yr, Length: 70000, dtype: float64

# %%
del df['id']

# %%
df
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0      18393       2     168    62.0    110     80            1     1      0
# 1      20228       1     156    85.0    140     90            3     1      0
# 2      18857       1     165    64.0    130     70            3     1      0
# 3      17623       2     169    82.0    150    100            1     1      0
# 4      17474       1     156    56.0    100     60            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995  19240       2     168    76.0    120     80            1     1      1
# 69996  22601       1     158   126.0    140     90            2     2      0
# 69997  19066       2     183   105.0    180     90            3     1      0
# 69998  22431       1     163    72.0    135     80            1     2      0
# 69999  20540       1     170    72.0    120     80            2     1      0
#
#        alco  active  cardio    yr
# ...

# %%
sns.countplot(data=df, x='yr',hue='cardio',palette='colorblind', edgecolor=sns.color_palette('dark', n_colors=1))
# Out:
# C:\Users\Anik\anaconda3\envs\MLenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Anik\anaconda3\envs\MLenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Anik\anaconda3\envs\MLenv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
df.describe()
# Out:
#                 age        gender        height        weight         ap_hi  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   19468.865814      1.349571    164.359229     74.205690    128.817286
# std     2467.251667      0.476838      8.210126     14.395757    154.011419
# min    10798.000000      1.000000     55.000000     10.000000   -150.000000
# 25%    17664.000000      1.000000    159.000000     65.000000    120.000000
# 50%    19703.000000      1.000000    165.000000     72.000000    120.000000
# 75%    21327.000000      2.000000    170.000000     82.000000    140.000000
# max    23713.000000      2.000000    250.000000    200.000000  16020.000000
#
#               ap_lo   cholesterol          gluc         smoke          alco  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      96.630414      1.366871      1.226457      0.088129      0.053771
# ...

# %%
df.corr()
# Out:
#                   age    gender    height    weight     ap_hi     ap_lo  \
# age          1.000000 -0.022811 -0.081515  0.053684  0.020764  0.017647
# gender      -0.022811  1.000000  0.499033  0.155406  0.006005  0.015254
# height      -0.081515  0.499033  1.000000  0.290968  0.005488  0.006150
# weight       0.053684  0.155406  0.290968  1.000000  0.030702  0.043710
# ap_hi        0.020764  0.006005  0.005488  0.030702  1.000000  0.016086
# ap_lo        0.017647  0.015254  0.006150  0.043710  0.016086  1.000000
# cholesterol  0.154424 -0.035821 -0.050226  0.141768  0.023778  0.024019
# gluc         0.098703 -0.020491 -0.018595  0.106857  0.011841  0.010806
# smoke       -0.047633  0.338135  0.187989  0.067780 -0.000922  0.005186
# alco        -0.029723  0.170966  0.094419  0.067113  0.001408  0.010601
# active      -0.009927  0.005866 -0.006570 -0.016867 -0.000033  0.004780
# cardio       0.238159  0.008109 -0.010821  0.181660  0.054475  0.065719
# ...

# %%
del df['yr']

# %%
df
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0      18393       2     168    62.0    110     80            1     1      0
# 1      20228       1     156    85.0    140     90            3     1      0
# 2      18857       1     165    64.0    130     70            3     1      0
# 3      17623       2     169    82.0    150    100            1     1      0
# 4      17474       1     156    56.0    100     60            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995  19240       2     168    76.0    120     80            1     1      1
# 69996  22601       1     158   126.0    140     90            2     2      0
# 69997  19066       2     183   105.0    180     90            3     1      0
# 69998  22431       1     163    72.0    135     80            1     2      0
# 69999  20540       1     170    72.0    120     80            2     1      0
#
#        alco  active  cardio
# ...

# %%
x = df.iloc[:,:-1]

# %%
x
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0      18393       2     168    62.0    110     80            1     1      0
# 1      20228       1     156    85.0    140     90            3     1      0
# 2      18857       1     165    64.0    130     70            3     1      0
# 3      17623       2     169    82.0    150    100            1     1      0
# 4      17474       1     156    56.0    100     60            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995  19240       2     168    76.0    120     80            1     1      1
# 69996  22601       1     158   126.0    140     90            2     2      0
# 69997  19066       2     183   105.0    180     90            3     1      0
# 69998  22431       1     163    72.0    135     80            1     2      0
# 69999  20540       1     170    72.0    120     80            2     1      0
#
#        alco  active
# 0         0       1
# ...

# %%
y = df['cardio']

# %%
y
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 69995    0
# 69996    1
# 69997    1
# 69998    1
# 69999    0
# Name: cardio, Length: 70000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y, test_size=.3,random_state=1)

# %%
xtrain
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 23561  16136       2     169    71.0    100     80            1     1      1
# 34858  14615       1     158    69.0    140     80            2     1      0
# 54953  20507       1     164    65.0    120     80            1     1      0
# 59230  16720       1     153    53.0    100     60            1     1      0
# 1730   21050       1     159    71.0    140     90            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 49100  21289       2     175    78.0    120     80            1     1      0
# 20609  19116       1     164    68.0    120     80            1     1      0
# 21440  18049       2     178    82.0    120     80            1     1      0
# 50057  21957       1     169    77.0    120     80            1     1      0
# 5192   20671       1     174    65.0    160     90            2     2      0
#
#        alco  active
# 23561     0       1
# ...

# %%
ytrain
# Out:
# 23561    0
# 34858    1
# 54953    0
# 59230    0
# 1730     1
#         ..
# 49100    1
# 20609    0
# 21440    0
# 50057    1
# 5192     1
# Name: cardio, Length: 49000, dtype: int64

# %%
xtest
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 6670   16099       1     153    93.0    140     90            1     1      0
# 49567  14437       1     157    89.0    120     80            1     1      0
# 50796  19839       1     165    66.0    150     90            1     1      0
# 22310  18050       2     176    88.0    160    100            2     2      1
# 54037  16819       2     165    78.0    140     90            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 15691  18263       1     170    70.0    120     80            1     1      0
# 25200  21081       1     165    60.0    120     70            3     1      0
# 7366   14716       1     170    68.0    100     60            1     1      0
# 56399  21998       1     165    66.0    110     80            1     1      0
# 31206  21103       1     163    64.0    120     80            1     1      0
#
#        alco  active
# 6670      0       1
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
Rclf = RandomForestClassifier()

# %%
Rclf.fit(x, y)
# Out:
# RandomForestClassifier()

# %%
Rclf.score(xtest,ytest)
# Out:
# 0.7161428571428572

# %%
Rclf = RandomForestClassifier()

# %%
rf_scores = cross_val_score(Rclf, x, y, cv=10)

# %%
print("Random Forest Classifier Cross-Validation Scores:", rf_scores)
print("Mean Accuracy:", rf_scores.mean())
# Out:
# Random Forest Classifier Cross-Validation Scores: [0.71428571 0.72380952 0.7        0.73333333 0.66666667 0.73333333
#  0.6952381  0.70952381 0.75238095 0.72857143 0.69047619 0.7
#  0.74761905 0.76190476 0.66666667 0.72380952 0.73809524 0.70952381
#  0.6952381  0.74285714 0.70952381 0.75238095 0.71904762 0.69047619
#  0.6952381  0.71904762 0.71904762 0.73333333 0.69047619 0.73333333
#  0.68571429 0.71904762 0.7047619  0.72380952 0.7047619  0.70952381
#  0.68571429 0.74285714 0.66190476 0.7047619  0.68095238 0.66190476
#  0.74761905 0.67619048 0.65714286 0.74285714 0.73809524 0.68095238
#  0.71904762 0.7047619  0.7047619  0.7047619  0.76666667 0.71904762
#  0.71428571 0.70952381 0.73809524 0.7047619  0.73809524 0.69047619
#  0.70952381 0.71904762 0.72857143 0.6952381  0.71428571 0.72380952
#  0.73333333 0.68095238 0.75714286 0.70952381 0.71904762 0.71428571
#  0.71904762 0.69047619 0.69047619 0.7047619  0.67619048 0.7
# ...

# %%
age = float(input("Enter age: "))
gender = int(input("Enter gender (1 for female, 2 for male): "))
height = float(input("Enter height: "))
weight = float(input("Enter weight: "))
ap_hi = float(input("Enter ap_hi: "))
ap_lo = float(input("Enter ap_lo: "))
cholesterol = int(input("Enter cholesterol level (1, 2, or 3): "))
gluc = int(input("Enter glucose level (1, 2, or 3): "))
smoke = int(input("Do you smoke? (0 for no, 1 for yes): "))
alco = int(input("Do you consume alcohol? (0 for no, 1 for yes): "))
active = int(input("Are you physically active? (0 for no, 1 for yes): "))

# Create a DataFrame with user input
user_input = pd.DataFrame({
    'age': [age],
    'gender': [gender],
    'height': [height],
    'weight': [weight],
    'ap_hi': [ap_hi],
    'ap_lo': [ap_lo],
    'cholesterol': [cholesterol],
    'gluc': [gluc],
    'smoke': [smoke],
    'alco': [alco],
    'active': [active]
})

# Predict cardio using RandomForestClassifier
rf_prediction = Rclf.predict(user_input)
rf_probability = Rclf.predict_proba(user_input)[:, 1]

# Predict cardio using DecisionTreeClassifier
dt_prediction = clf.predict(user_input)

print("Random Forest Classifier Prediction (0 for no, 1 for yes):", rf_prediction[0])
print("Random Forest Classifier Probability:", rf_probability[0])
print("Decision Tree Classifier Prediction (0 for no, 1 for yes):", dt_prediction[0])
# Out:
# Enter age: 55
# Enter gender (1 for female, 2 for male): 2
# Enter height: 175
# Enter weight: 85
# Enter ap_hi: 140
# Enter ap_lo: 90
# Enter cholesterol level (1, 2, or 3): 3
# Enter glucose level (1, 2, or 3): 2
# Do you smoke? (0 for no, 1 for yes): 1
# Do you consume alcohol? (0 for no, 1 for yes): 0
# Are you physically active? (0 for no, 1 for yes): 1
# Random Forest Classifier Prediction (0 for no, 1 for yes): 1
# Random Forest Classifier Probability: 0.71
# Decision Tree Classifier Prediction (0 for no, 1 for yes): 0
